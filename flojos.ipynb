# %% [markdown]
# <a href="https://colab.research.google.com/github/hthomas229/IAAO_Exams/blob/main/flojos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Combine Cusomer Order Files

# %% [markdown]
# import the necessary Python packages

# %%
import csv
from pathlib import Path
import pandas as pd

# %% [markdown]
# clean column names

# %% [markdown]
# Define a unified schema for output data

# %%
UNIFIED_SCHEMA = ['PO', 'PO DATE', 'START SHIP', 'CANCEL SHIP', 'STYLE #', 'SIZE', 'QTY', 'STYLE & SIZE', 'UPC', 'COST', 'DISCOUNT' ]

# %%
costco_mapping = {
    'PO Number' : 'PO',
    'PO Date'  : 'PO DATE',
    'Ship Dates'  : 'START SHIP',
    'Cancel Date' : 'CANCEL SHIP',
    'Product/Item Description'   : 'STYLE #',
    'Size'   :  'SIZE',
    'Qty Ordered'  : 'QTY',
    'Color' : 'STYLE & SIZE',
    'Buyers Catalog or Stock Keeping #' : 'UPC',
    "Unit Price" : "COST",
    "Payment Terms Disc Amt" : "DISCOUNT"

}

# %%
outside_equipped_mapping  = {
    'PONumber' : 'PO',
    'OrderDate'  : 'PO DATE',
    'ProductName'   : 'STYLE #',
    'ProductSize'   :  'SIZE',
    'ProductQuantity'  : 'QTY',
    'ProductColor' : 'STYLE & SIZE',
    'ProductSKU' : 'UPC',
    "Price" : "COST"



}

# %% [markdown]
# Define list of customer file paths

# %%
customer_file_paths = [
    '/content/costco.csv',
    '/content/outdoor_equipped.csv'

]

# %% [markdown]
# Create empty array to store data

# %%
def apply_mapping(vendor_name, row):
    """Applies the appropriate mapping based on the vendor name."""
    if vendor_name == 'costco':
        mapping = costco_mapping
    elif vendor_name == 'outdoor_equipped':
        mapping = outside_equipped_mapping
    else:
        return None # Or handle unknown vendors as needed

    mapped_row = {}
    for original_col, unified_col in mapping.items():
        if original_col in row:
            mapped_row[unified_col] = row[original_col]
    return mapped_row

processed_data = []

# %% [markdown]
# Iterate through each vendor file

# %%
for file_path in customer_file_paths:
  try:
    # get customer name from file path
    customer_name = Path(file_path).stem

    #read csv to Pandas dataframe
    df=pd.read_csv(file_path)

    #iterate through the Data frame and apply mapping
    for index, row in df.iterrows():
      mapped_row = apply_mapping(customer_name, row.to_dict())
      if mapped_row: # Check if mapping returned a valid row
          # Ensure the mapped row has all columns from the unified schema, filling missing with None
          full_mapped_row = {col: mapped_row.get(col) for col in UNIFIED_SCHEMA}
          processed_data.append(full_mapped_row)

  except FileNotFoundError:
      print(f"Error: File not found at {file_path}. Skipping.")
  except Exception as e:
      print(f"Error processing file {file_path}: {e}")

# %%
processed_data
# Out:
# [{'PO': 1790220636,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 5040.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 13860220207,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 18144.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1790220655,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 7680.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1710220308,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '3/1/2025',
#   'CANCEL SHIP': '3/1/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1750220315,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 17136.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1710220310,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 4032.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1790220652,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1710220325,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1750220324,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1710220326,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '3/1/2025',
#   'CANCEL SHIP': '3/1/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1750220323,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 10520220286,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/27/2025',
#   'CANCEL SHIP': '2/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 1008.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 12030220319,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/27/2025',
#   'CANCEL SHIP': '2/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 15120.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1790220635,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '3/2/2025',
#   'CANCEL SHIP': '3/2/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 10520220288,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 10520220290,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/27/2025',
#   'CANCEL SHIP': '2/27/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 1536.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600220431,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 7680.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1790220654,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '3/2/2025',
#   'CANCEL SHIP': '3/2/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 10520220285,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 13540220217,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 4032.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 13760220269,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/27/2025',
#   'CANCEL SHIP': '2/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 8064.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600220401,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 12030220324,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9360220236,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 15360.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1790220633,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 13760220273,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 13760220268,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 13540220216,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 12030220318,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600220402,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/27/2025',
#   'CANCEL SHIP': '2/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 12030220325,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/27/2025',
#   'CANCEL SHIP': '2/27/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 23040.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1710220328,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 6144.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1710220309,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 6048.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 10520220289,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1740220256,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 1536.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 13540220219,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 30720.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 10520220284,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/28/2025',
#   'CANCEL SHIP': '2/28/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 13540220220,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 6144.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600220404,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 16128.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600220403,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '3/2/2025',
#   'CANCEL SHIP': '3/2/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 11088.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600220904,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '3/4/2025',
#   'CANCEL SHIP': '3/4/2025',
#   'STYLE #': nan,
#   'SIZE': nan,
#   'QTY': nan,
#   'STYLE & SIZE': nan,
#   'UPC': nan,
#   'COST': nan,
#   'DISCOUNT': None},
#  {'PO': 9600220903,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '3/4/2025',
#   'CANCEL SHIP': '3/4/2025',
#   'STYLE #': nan,
#   'SIZE': nan,
#   'QTY': nan,
#   'STYLE & SIZE': nan,
#   'UPC': nan,
#   'COST': nan,
#   'DISCOUNT': None},
#  {'PO': 2880220226,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': nan,
#   'SIZE': nan,
#   'QTY': nan,
#   'STYLE & SIZE': nan,
#   'UPC': nan,
#   'COST': nan,
#   'DISCOUNT': None},
#  {'PO': 2880220230,
#   'PO DATE': '2/20/2025',
#   'START SHIP': '2/26/2025',
#   'CANCEL SHIP': '2/26/2025',
#   'STYLE #': nan,
#   'SIZE': nan,
#   'QTY': nan,
#   'STYLE & SIZE': nan,
#   'UPC': nan,
#   'COST': nan,
#   'DISCOUNT': None},
#  {'PO': 9360310320,
#   'PO DATE': '3/10/2025',
#   'START SHIP': '3/14/2025',
#   'CANCEL SHIP': '3/14/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 4608.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1790310547,
#   'PO DATE': '3/10/2025',
#   'START SHIP': '3/14/2025',
#   'CANCEL SHIP': '3/14/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 5120.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600310751,
#   'PO DATE': '3/10/2025',
#   'START SHIP': '3/13/2025',
#   'CANCEL SHIP': '3/13/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 3584.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600310764,
#   'PO DATE': '3/10/2025',
#   'START SHIP': '3/13/2025',
#   'CANCEL SHIP': '3/13/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 2016.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600310765,
#   'PO DATE': '3/10/2025',
#   'START SHIP': '3/13/2025',
#   'CANCEL SHIP': '3/13/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 1680.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600310749,
#   'PO DATE': '3/10/2025',
#   'START SHIP': '3/13/2025',
#   'CANCEL SHIP': '3/13/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 12800.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600314799,
#   'PO DATE': '3/14/2025',
#   'START SHIP': '3/19/2025',
#   'CANCEL SHIP': '3/19/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 2048.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600314800,
#   'PO DATE': '3/14/2025',
#   'START SHIP': '3/19/2025',
#   'CANCEL SHIP': '3/19/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 2688.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 2880317277,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600317894,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 4032.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1790317588,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/20/2025',
#   'CANCEL SHIP': '3/20/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1710317753,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 5840317349,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 1024.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 13860317316,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 5040.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9360317398,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 7680.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600317891,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600317888,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 25600.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600317893,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/20/2025',
#   'CANCEL SHIP': '3/20/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 2620317553,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/20/2025',
#   'CANCEL SHIP': '3/20/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 4608.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 2620317556,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/20/2025',
#   'CANCEL SHIP': '3/20/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1790317583,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 28672.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 13540317280,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 13860317315,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 1536.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9360317400,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 18144.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1750317508,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600317889,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 11264.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 9600317892,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/24/2025',
#   'CANCEL SHIP': '3/24/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1790317589,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 9600317890,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/20/2025',
#   'CANCEL SHIP': '3/20/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 10520317370,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/24/2025',
#   'CANCEL SHIP': '3/24/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 7680.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 12030317348,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 2688.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 10520317373,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1750317504,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/20/2025',
#   'CANCEL SHIP': '3/20/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 4608.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 2880317275,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 3072.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 2620317557,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 10080.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 5840317354,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 8064.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1740317465,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/24/2025',
#   'CANCEL SHIP': '3/24/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 1536.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 13540317278,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 5120.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1790317590,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 20160.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 10520317374,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 5040.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1710317746,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS LADIES FLIP FLOP   FY25                 P512',
#   'SIZE': nan,
#   'QTY': 4096.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856396.0,
#   'COST': 12.57,
#   'DISCOUNT': None},
#  {'PO': 1740317467,
#   'PO DATE': '3/17/2025',
#   'START SHIP': '3/21/2025',
#   'CANCEL SHIP': '3/21/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 3024.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1790324343,
#   'PO DATE': '3/24/2025',
#   'START SHIP': '3/27/2025',
#   'CANCEL SHIP': '3/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 7728.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 10520324343,
#   'PO DATE': '3/24/2025',
#   'START SHIP': '3/27/2025',
#   'CANCEL SHIP': '3/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 2016.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 13540324236,
#   'PO DATE': '3/24/2025',
#   'START SHIP': '3/27/2025',
#   'CANCEL SHIP': '3/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 672.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1750324457,
#   'PO DATE': '3/24/2025',
#   'START SHIP': '3/27/2025',
#   'CANCEL SHIP': '3/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 13104.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 12030324347,
#   'PO DATE': '3/24/2025',
#   'START SHIP': '3/27/2025',
#   'CANCEL SHIP': '3/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 1008.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 1740324320,
#   'PO DATE': '3/24/2025',
#   'START SHIP': '3/27/2025',
#   'CANCEL SHIP': '3/27/2025',
#   'STYLE #': 'FLOJOS MENS FLIP FLOP     FY25                P336',
#   'SIZE': nan,
#   'QTY': 1008.0,
#   'STYLE & SIZE': nan,
#   'UPC': 1856398.0,
#   'COST': 13.96,
#   'DISCOUNT': None},
#  {'PO': 325680810,
#   'PO DATE': '7/31/2025 0:00',
#   'START SHIP': None,
#   'CANCEL SHIP': None,
#   'STYLE #': "Flojos Women's Olivia Black/Brown Flip-Flip 8 M US",
#   'SIZE': nan,
#   'QTY': 1,
#   'STYLE & SIZE': nan,
#   'UPC': 'FJ-261_BLACK/BROWN_8',
#   'COST': 17.0,
#   'DISCOUNT': None},
#  {'PO': 325688540,
#   'PO DATE': '7/31/2025 0:00',
#   'START SHIP': None,
#   'CANCEL SHIP': None,
#   'STYLE #': "Flojos Women's Sky Dress Sandal",
#   'SIZE': 10.0,
#   'QTY': 1,
#   'STYLE & SIZE': ' Tan',
#   'UPC': 'FJ-171_TAN_10',
#   'COST': 13.5,
#   'DISCOUNT': None},
#  {'PO': 325698608,
#   'PO DATE': '7/31/2025 0:00',
#   'START SHIP': None,
#   'CANCEL SHIP': None,
#   'STYLE #': "Flojos Women's Sky Dress Sandal",
#   'SIZE': 8.0,
#   'QTY': 1,
#   'STYLE & SIZE': ' Tan',
#   'UPC': 'FJ-171_TAN_8',
#   'COST': 13.5,
#   'DISCOUNT': None},
#  {'PO': 325694946,
#   'PO DATE': '7/31/2025 0:00',
#   'START SHIP': None,
#   'CANCEL SHIP': None,
#   'STYLE #': "Flojos Women's Sky Dress Sandal",
#   'SIZE': 10.0,
#   'QTY': 1,
#   'STYLE & SIZE': ' Tan',
#   'UPC': 'FJ-171_TAN_10',
#   'COST': 13.5,
#   'DISCOUNT': None},
#  {'PO': 325713286,
#   'PO DATE': '7/31/2025 0:00',
#   'START SHIP': None,
#   'CANCEL SHIP': None,
#   'STYLE #': "FLOJOS Women's Spark Flip-Flop",
#   'SIZE': 7.0,
#   'QTY': 1,
#   'STYLE & SIZE': ' Black',
#   'UPC': 'FJ-232_BLACK_7',
#   'COST': 13.5,
#   'DISCOUNT': None}]

# %%
combined_df = pd.DataFrame(processed_data)
combined_df.to_csv('combined_customer_orders.csv', index=False)
